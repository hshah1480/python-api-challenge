# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.6.tar.gz (675 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 675.6/675.6 kB 3.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting kdtree>=0.12 (from citipy)
#   Downloading kdtree-0.16-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py) ... done
#   Created wheel for citipy: filename=citipy-0.0.6-py3-none-any.whl size=675967 sha256=41f749cb9a6df785d2453ec58c123b4f89a350c11bc75238a5b04113604d6812
#   Stored in directory: /Users/sonyshah/Library/Caches/pip/wheels/4b/b5/88/49107ff846ec6967b34c17d369176c591fc90ed93b706755ad
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.6 kdtree-0.16

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 623

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + "&q=phoenix")
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=metric&appid=cb8372df8540a79d16689eb2685ddda7&q=phoenix

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sur
# Processing Record 2 of Set 1 | revda
# Processing Record 3 of Set 1 | ugine
# Processing Record 4 of Set 1 | dunedin
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | san antonio de pale
# Processing Record 7 of Set 1 | waitangi
# Processing Record 8 of Set 1 | qaqortoq
# Processing Record 9 of Set 1 | isafjordur
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | sandnessjoen
# City not found. Skipping...
# Processing Record 12 of Set 1 | namibe
# Processing Record 13 of Set 1 | buka
# Processing Record 14 of Set 1 | ilhabela
# Processing Record 15 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 16 of Set 1 | la'ie
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | queenstown
# Processing Record 19 of Set 1 | grytviken
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | talnakh
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | juneau
# Processing Record 24 of Set 1 | severo-yeniseyskiy
# Processing Record 25 of Set 1 | edinburgh of the seven seas
# Processing Record 26 of Set 1 | zhangye
# Processing Record 27 of Set 1 | vorgashor
# Processing Record 28 of Set 1 | enewetak
# Processing Record 29 of Set 1 | yangor
# City not found. Skipping...
# Processing Record 30 of Set 1 | north bend
# Processing Record 31 of Set 1 | puerto natales
# Processing Record 32 of Set 1 | luderitz
# Processing Record 33 of Set 1 | anadyr
# Processing Record 34 of Set 1 | pasni
# Processing Record 35 of Set 1 | bilibino
# Processing Record 36 of Set 1 | fort bragg
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | port lincoln
# Processing Record 39 of Set 1 | izhevsk
# Processing Record 40 of Set 1 | st. john's
# Processing Record 41 of Set 1 | buala
# Processing Record 42 of Set 1 | fonadhoo
# City not found. Skipping...
# Processing Record 43 of Set 1 | necochea
# Processing Record 44 of Set 1 | gaspe
# Processing Record 45 of Set 1 | moose jaw
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | brookings
# Processing Record 49 of Set 1 | byndoor
# Processing Record 50 of Set 1 | canutama
# Processing Record 0 of Set 2 | gamboma
# Processing Record 1 of Set 2 | chonchi
# Processing Record 2 of Set 2 | callao
# Processing Record 3 of Set 2 | ad dilam
# Processing Record 4 of Set 2 | jaicos
# Processing Record 5 of Set 2 | margaret river
# Processing Record 6 of Set 2 | ulaangom
# Processing Record 7 of Set 2 | utrik
# Processing Record 8 of Set 2 | hawaiian paradise park
# Processing Record 9 of Set 2 | ain beni mathar
# City not found. Skipping...
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | saipan
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | coahuayana de hidalgo
# Processing Record 15 of Set 2 | nuuk
# Processing Record 16 of Set 2 | alofi
# Processing Record 17 of Set 2 | isla mujeres
# Processing Record 18 of Set 2 | kulhudhuffushi
# Processing Record 19 of Set 2 | kerman
# Processing Record 20 of Set 2 | tindouf
# Processing Record 21 of Set 2 | taltal
# Processing Record 22 of Set 2 | invercargill
# Processing Record 23 of Set 2 | ola
# Processing Record 24 of Set 2 | undurkhaan
# Processing Record 25 of Set 2 | port douglas
# Processing Record 26 of Set 2 | winkler
# Processing Record 27 of Set 2 | namtsy
# Processing Record 28 of Set 2 | fale old settlement
# Processing Record 29 of Set 2 | peringat
# Processing Record 30 of Set 2 | atafu village
# Processing Record 31 of Set 2 | forster
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 
# Processing Record 11 of Set 4 | mikun'
# Processing Record 12 of Set 4 | avarua
# Processing Record 13 of Set 4 | olonkinbyen
# Processing Record 14 of Set 4 | askino
# Processing Record 15 of Set 4 | amos
# Processing Record 16 of Set 4 | jiaojiang
# Processing Record 17 of Set 4 | tazovsky
# Processing Record 18 of Set 4 | college
# Processing Record 19 of Set 4 | pemangkat
# Processing Record 20 of Set 4 | stanley
# Processing Record 21 of Set 4 | charters towers
# Processing Record 22 of Set 4 | malango
# Processing Record 23 of Set 4 | codrington
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | bangolo
# Processing Record 27 of Set 4 | santyoku
# Processing Record 28 of Set 4 | chickasha
# Processing Record 29 of Set 4 | nema
# Processing Record 30 of Set 4 | toropets
# Processing Record 31 of Set 4 | xinmin
# Processing Record 32 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 33 of Set 4 | arauca
# Processing Record 34 of Set 4 | lowestoft
# Processing Record 35 of Set 4 | minas de marcona
# Processing Record 36 of Set 4 | kailua-kona
# Processing Record 37 of Set 4 | vorkuta
# Processing Record 38 of Set 4 | hamilton
# Processing Record 39 of Set 4 | holualoa
# Processing Record 40 of Set 4 | san patricio
# Processing Record 41 of Set 4 | beyneu
# Processing Record 42 of Set 4 | qasr-e qand
# City not found. Skipping...
# Processing Record 43 of Set 4 | weno
# Processing Record 44 of Set 4 | tolanaro
# Processing Record 45 of Set 4 | turkmenbasy
# Processing Record 46 of Set 4 | hami
# Processing Record 47 of Set 4 | crete
# Processing Record 48 of Set 4 | padang
# Processing Record 49 of Set 4 | road town
# Processing Record 0 of Set 5 | cadale
# Processing Record 1 of Set 5 | bikenibeu village
# Processing Record 2 of Set 5 | korla
# Processing Record 3 of Set 5 | whitehorse
# Processing Record 4 of Set 5 | illizi
# Processing Record 5 of Set 5 | oryahovo
# Processing Record 6 of Set 5 | hermanus
# Processing Record 7 of Set 5 | geraldton
# Processing Record 8 of Set 5 | puerto gaitan
# Processing Record 9 of Set 5 | flying fish cove
# Processing Record 10 of Set 5 | petauke
# Processing Record 11 of Set 5 | veraval
# Processing Record 12 of Set 5 | susuman
# Processing Record 13 of Set 5 | gadzhiyevo
# Processing Record 14 of Set 5 | adrar
# Processing Record 15 of Set 5 | zabol
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | uturoa
# Processing Record 18 of Set 5 | ibusuki
# Processing Record 19 of Set 5 | badiyah
# Processing Record 20 of Set 5 | fredrikstad
# Processing Record 21 of Set 5 | turpan
# Processing Record 22 of Set 5 | san luis
# Processing Record 23 of Set 5 | elliot lake
# Processing Record 24 of Set 5 | mawu
# Processing Record 25 of Set 5 | zambezi
# Processing Record 26 of Set 5 | urucara
# Processing Record 27 of Set 5 | usogorsk
# Processing Record 28 of Set 5 | patacamaya
# Processing Record 29 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 30 of Set 5 | ancud
# Processing Record 31 of Set 5 | envira
# Processing Record 32 of Set 5 | city of balikpapan
# Processing Record 33 of Set 5 | baki
# Processing Record 34 of Set 5 | rio grande
# Processing Record 35 of Set 5 | aasiaat
# Processing Record 36 of Set 5 | pyhajarvi
# Processing Record 37 of Set 5 | badger
# Processing Record 38 of Set 5 | mejit
# Processing Record 39 of Set 5 | nadym
# Processing Record 40 of Set 5 | lamu
# Processing Record 41 of Set 5 | mont-dore
# Processing Record 42 of Set 5 | ataq
# Processing Record 43 of Set 5 | shetpe
# Processing Record 44 of Set 5 | pushkino
# Processing Record 45 of Set 5 | walvis bay
# Processing Record 46 of Set 5 | ghanzi
# Processing Record 47 of Set 5 | vedaraniyam
# Processing Record 48 of Set 5 | udachny
# Processing Record 49 of Set 5 | saint johnsbury
# Processing Record 0 of Set 6 | lazaro cardenas
# Processing Record 1 of Set 6 | kapa'a
# Processing Record 2 of Set 6 | sittwe
# Processing Record 3 of Set 6 | bastrop
# Processing Record 4 of Set 6 | ungsang-nodongjagu
# Processing Record 5 of Set 6 | ondjiva
# Processing Record 6 of Set 6 | east glenville
# Processing Record 7 of Set 6 | gizo
# Processing Record 8 of Set 6 | reitz
# Processing Record 9 of Set 6 | amasra
# Processing Record 10 of Set 6 | kayangel
# Processing Record 11 of Set 6 | keflavik
# Processing Record 12 of Set 6 | tralee
# Processing Record 13 of Set 6 | dudinka
# Processing Record 14 of Set 6 | broken hill
# Processing Record 15 of Set 6 | gazli
# Processing Record 16 of Set 6 | marang
# Processing Record 17 of Set 6 | tazacorte
# Processing Record 18 of Set 6 | moab
# Processing Record 19 of Set 6 | carnarvon
# Processing Record 20 of Set 6 | slave lake
# Processing Record 21 of Set 6 | puerto colombia
# Processing Record 22 of Set 6 | rawah
# Processing Record 23 of Set 6 | dalandzadgad
# Processing Record 24 of Set 6 | umm kaddadah
# Processing Record 25 of Set 6 | oranjemund
# Processing Record 26 of Set 6 | cidreira
# Processing Record 27 of Set 6 | port macquarie
# Processing Record 28 of Set 6 | margate
# Processing Record 29 of Set 6 | palm beach
# Processing Record 30 of Set 6 | kalmunai
# Processing Record 31 of Set 6 | nikel
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | hilo
# Processing Record 34 of Set 6 | erenhot
# Processing Record 35 of Set 6 | sunne
# Processing Record 36 of Set 6 | piti village
# Processing Record 37 of Set 6 | newman
# Processing Record 38 of Set 6 | kismayo
# Processing Record 39 of Set 6 | tabou
# Processing Record 40 of Set 6 | la punta
# Processing Record 41 of Set 6 | skeldon
# Processing Record 42 of Set 6 | saint-pierre
# Processing Record 43 of Set 6 | mata-utu
# Processing Record 44 of Set 6 | victorica
# Processing Record 45 of Set 6 | labytnangi
# Processing Record 46 of Set 6 | sarandi grande
# Processing Record 47 of Set 6 | port mathurin
# Processing Record 48 of Set 6 | east liverpool
# Processing Record 49 of Set 6 | north perth
# Processing Record 0 of Set 7 | talara
# Processing Record 1 of Set 7 | bocaiuva
# Processing Record 2 of Set 7 | al hasaheisa
# Processing Record 3 of Set 7 | nagqu
# Processing Record 4 of Set 7 | douz
# Processing Record 5 of Set 7 | tabas
# Processing Record 6 of Set 7 | zhanaozen
# Processing Record 7 of Set 7 | riosucio
# Processing Record 8 of Set 7 | narsingdi
# Processing Record 47 of Set 9 | floro
# Processing Record 48 of Set 9 | meadow lakes
# Processing Record 49 of Set 9 | atherton
# Processing Record 0 of Set 10 | hadibu
# Processing Record 1 of Set 10 | al mijlad
# Processing Record 2 of Set 10 | san luis de la loma
# Processing Record 3 of Set 10 | kerikeri
# Processing Record 4 of Set 10 | vilyuchinsk
# Processing Record 5 of Set 10 | malanje
# Processing Record 6 of Set 10 | northam
# Processing Record 7 of Set 10 | nouadhibou
# Processing Record 8 of Set 10 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 9 of Set 10 | pitea
# Processing Record 10 of Set 10 | mount isa
# Processing Record 11 of Set 10 | xiongzhou
# Processing Record 12 of Set 10 | katsuren-haebaru
# Processing Record 13 of Set 10 | ryotsu-minato
# Processing Record 14 of Set 10 | tyumen
# Processing Record 15 of Set 10 | villa gesell
# Processing Record 16 of Set 10 | ambanja
# Processing Record 17 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 18 of Set 10 | richards bay
# Processing Record 19 of Set 10 | brenham
# Processing Record 20 of Set 10 | dhidhdhoo
# Processing Record 21 of Set 10 | brooks
# Processing Record 22 of Set 10 | nandgaon
# Processing Record 23 of Set 10 | flin flon
# Processing Record 24 of Set 10 | luorong
# Processing Record 25 of Set 10 | severnoye
# Processing Record 26 of Set 10 | soio
# Processing Record 27 of Set 10 | orai
# Processing Record 28 of Set 10 | port moresby
# Processing Record 29 of Set 10 | alakurtti
# Processing Record 30 of Set 10 | marco island
# Processing Record 31 of Set 10 | chernyshevsk
# Processing Record 32 of Set 10 | alice springs
# Processing Record 33 of Set 10 | salekhard
# Processing Record 34 of Set 10 | taman rajawali
# City not found. Skipping...
# Processing Record 35 of Set 10 | darwin
# Processing Record 36 of Set 10 | umred
# Processing Record 37 of Set 10 | shache
# Processing Record 38 of Set 10 | muzayri'
# City not found. Skipping...
# Processing Record 39 of Set 10 | phaphund
# Processing Record 40 of Set 10 | ostroda
# Processing Record 41 of Set 10 | harstad
# Processing Record 42 of Set 10 | tamanrasset
# Processing Record 43 of Set 10 | lincoln
# Processing Record 44 of Set 10 | hotan
# Processing Record 45 of Set 10 | nyandoma
# Processing Record 46 of Set 10 | at taj
# Processing Record 47 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 48 of Set 10 | saint-joseph
# Processing Record 49 of Set 10 | ta`u
# Processing Record 0 of Set 11 | gangapur
# Processing Record 1 of Set 11 | cabo san lucas
# Processing Record 2 of Set 11 | groningen
# Processing Record 3 of Set 11 | prince rupert
# Processing Record 4 of Set 11 | shimo-furano
# Processing Record 5 of Set 11 | jakobstad
# Processing Record 6 of Set 11 | hojo
# Processing Record 7 of Set 11 | coari
# Processing Record 8 of Set 11 | dubbo
# Processing Record 9 of Set 11 | birobidzhan
# Processing Record 10 of Set 11 | medina
# Processing Record 11 of Set 11 | bonthe
# Processing Record 12 of Set 11 | poplar bluff
# Processing Record 13 of Set 11 | cable beach
# City not found. Skipping...
# Processing Record 14 of Set 11 | barcelos
# Processing Record 15 of Set 11 | uaboe
# City not found. Skipping...
# Processing Record 16 of Set 11 | jaisalmer
# Processing Record 17 of Set 11 | sedrata
# Processing Record 18 of Set 11 | lorengau
# Processing Record 19 of Set 11 | trnava
# Processing Record 20 of Set 11 | shingu
# Processing Record 21 of Set 11 | nkurenkuru
# City not found. Skipping...
# Processing Record 22 of Set 11 | kyren
# Processing Record 23 of Set 11 | greymouth
# Processing Record 24 of Set 11 | n'zeto
# Processing Record 25 of Set 11 | kiunga
# Processing Record 26 of Set 11 | saraktash
# Processing Record 27 of Set 11 | tobruk
# Processing Record 28 of Set 11 | quatre cocos
# Processing Record 29 of Set 11 | mount pearl
# Processing Record 30 of Set 11 | dingcheng
# Processing Record 31 of Set 11 | pokrov
# Processing Record 32 of Set 11 | ballina
# Processing Record 33 of Set 11 | tateyama
# Processing Record 34 of Set 11 | bomdila
# Processing Record 35 of Set 11 | naze
# Processing Record 36 of Set 11 | horta
# Processing Record 37 of Set 11 | ozu
# Processing Record 38 of Set 11 | tofol
# Processing Record 39 of Set 11 | kindu
# Processing Record 40 of Set 11 | elmendorf air force base
# City not found. Skipping...
# Processing Record 41 of Set 11 | lubliniec
# Processing Record 42 of Set 11 | petropavlovsk-kamchatsky
# Processing Record 43 of Set 11 | tinaquillo
# Processing Record 44 of Set 11 | vila franca do campo
# Processing Record 45 of Set 11 | sosnovka
# Processing Record 46 of Set 11 | osakarovka
# Processing Record 47 of Set 11 | along
# Processing Record 48 of Set 11 | villa mercedes
# Processing Record 49 of Set 11 | ocean pointe
# City not found. Skipping...
# Processing Record 0 of Set 12 | mont-roig del camp
# Processing Record 1 of Set 12 | atbara
# Processing Record 2 of Set 12 | nova vicosa
# Processing Record 3 of Set 12 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 12 | igarka
# Processing Record 5 of Set 12 | general salgado
# Processing Record 6 of Set 12 | afaahiti
# Processing Record 7 of Set 12 | el oued
# Processing Record 8 of Set 12 | ipua
# Processing Record 9 of Set 12 | qarazhal
# Processing Record 10 of Set 12 | udomlya
# Processing Record 11 of Set 12 | benalla
# Processing Record 12 of Set 12 | okhotsk
# Processing Record 13 of Set 12 | acapulco de juarez
# Processing Record 14 of Set 12 | trenggalek
# Processing Record 15 of Set 12 | neiafu
# Processing Record 16 of Set 12 | libreville
# Processing Record 17 of Set 12 | polessk
# Processing Record 18 of Set 12 | mermoz boabab
# Processing Record 19 of Set 12 | ketchikan
# Processing Record 20 of Set 12 | nishinoomote
# Processing Record 21 of Set 12 | dakoro
# Processing Record 22 of Set 12 | borogontsy
# Processing Record 23 of Set 12 | qingdao
# Processing Record 24 of Set 12 | eureka
# Processing Record 25 of Set 12 | qarauyl
# Processing Record 26 of Set 12 | kodinsk
# Processing Record 27 of Set 12 | kapuskasing
# Processing Record 28 of Set 12 | mareeba
# Processing Record 29 of Set 12 | vila velha
# Processing Record 30 of Set 12 | taoudenni
# Processing Record 31 of Set 12 | kingisepp
# Processing Record 32 of Set 12 | shenjiamen
# Processing Record 33 of Set 12 | devinuwara
# City not found. Skipping...
# Processing Record 34 of Set 12 | jian'ou
# Processing Record 35 of Set 12 | miri
# Processing Record 36 of Set 12 | haciqabul
# Processing Record 37 of Set 12 | mana
# Processing Record 38 of Set 12 | kilju
# Processing Record 39 of Set 12 | mangrol
# Processing Record 40 of Set 12 | chhota udepur
# Processing Record 41 of Set 12 | kenora
# Processing Record 42 of Set 12 | la passe
# Processing Record 43 of Set 12 | binuangan
# Processing Record 44 of Set 12 | i-n-salah
# Processing Record 45 of Set 12 | mandera
# Processing Record 46 of Set 12 | tongliao
# Processing Record 47 of Set 12 | driefontein
# Processing Record 48 of Set 12 | zaysan
# Processing Record 49 of Set 12 | urbana
# Processing Record 0 of Set 13 | seosan
# Processing Record 1 of Set 13 | burutu
# Processing Record 2 of Set 13 | ulladulla
# Processing Record 3 of Set 13 | suoyarvi
# Processing Record 4 of Set 13 | mejdan - obilicevo
# City not found. Skipping...
# Processing Record 5 of Set 13 | betio village
# Processing Record 6 of Set 13 | seka
# Processing Record 7 of Set 13 | hayma'
# City not found. Skipping...
# Processing Record 8 of Set 13 | szentgotthard
# Processing Record 9 of Set 13 | brisas de zicatela
# Processing Record 10 of Set 13 | kolonia town
# Processing Record 11 of Set 13 | vingt cinq
# City not found. Skipping...
# Processing Record 12 of Set 13 | ujae
# Processing Record 13 of Set 13 | kaka
# Processing Record 14 of Set 13 | papao
# Processing Record 15 of Set 13 | nasir
# Processing Record 16 of Set 13 | sal rei
# Processing Record 17 of Set 13 | sao vicente
# Processing Record 18 of Set 13 | grootfontein
# Processing Record 19 of Set 13 | yelizovo
# Processing Record 20 of Set 13 | zhosaly
# Processing Record 21 of Set 13 | thanh hoa
# Processing Record 22 of Set 13 | xinyuan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          587
# Lat           587
# Lng           587
# Max Temp      587
# Humidity      587
# Cloudiness    587
# Wind Speed    587
# Country       587
# Date          587
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                sur  22.5667   59.5289     38.65        31          86
# 1              revda  56.8010   59.9303     10.87        91         100
# 2              ugine  45.7508    6.4161     19.82        92          65
# 3            dunedin -45.8742  170.5036      9.33        89          99
# 4  port-aux-francais -49.3500   70.2167      2.13        86         100
#
#    Wind Speed Country        Date
# 0        0.72      OM  1722144766
# 1        5.48      RU  1722144778
# 2        0.72      FR  1722144792
# 3        0.45      NZ  1722144804
# 4       15.82      TF  1722144833

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                      sur  22.5667   59.5289     38.65        31          86
# 1                    revda  56.8010   59.9303     10.87        91         100
# 2                    ugine  45.7508    6.4161     19.82        92          65
# 3                  dunedin -45.8742  170.5036      9.33        89          99
# 4        port-aux-francais -49.3500   70.2167      2.13        86         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.72      OM  1722144766
# 1              5.48      RU  1722144778
# 2              0.72      FR  1722144792
# 3              0.45      NZ  1722144804
# 4             15.82      TF  1722144833

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="green",
    linewidths=1,
    marker="o",
    # markercolor="green",
    alpha=0.7,
    label="cities"
   
)

# Incorporate the other graph properties
date = time.strftime("%d-%m-%Y")
plt.title(f"City Latitude vs. Max Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="brown",
    linewidths=1,
    marker="o",
    alpha=0.7,
    label="cities"
   
)
# Incorporate the other graph properties
date = time.strftime("%d-%m-%Y")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="aqua",
    linewidths=1,
    marker="o",
    alpha=0.7,
    label="cities"
)
# Incorporate the other graph properties
date = time.strftime("%d-%m-%Y")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.7,
    label="cities"
)

# Incorporate the other graph properties
date = time.strftime("%d-%m-%Y")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):
    # compute linear regression
    (slope, intercept,rvalue, pvalue,stderr)=linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue ** 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[city_data_df["Lat"] >=0]
# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               sur  22.5667  59.5289     38.65        31          86
# 1             revda  56.8010  59.9303     10.87        91         100
# 2             ugine  45.7508   6.4161     19.82        92          65
# 7          qaqortoq  60.7167 -46.0333      3.59        92          99
# 8        isafjordur  66.0755 -23.1240      8.06        81         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.72      OM  1722144766
# 1              5.48      RU  1722144778
# 2              0.72      FR  1722144792
# 7              2.03      GL  1722144933
# 8              3.55      IS  1722144946

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df["Lat"] <0]
# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 3                    dunedin -45.8742  170.5036      9.33        89
# 4          port-aux-francais -49.3500   70.2167      2.13        86
# 5        san antonio de pale  -1.4014    5.6325     22.87        84
# 6                   waitangi -43.9535 -176.5597     11.01        89
# 9                  adamstown -25.0660 -130.1015     20.69        83
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 3                99        0.45      NZ  1722144804
# 4               100       15.82      TF  1722144833
# 5                70        6.96      GQ  1722144882
# 6                28        2.24      NZ  1722144921
# 9                94        5.57      PN  1722144980

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

plot_linear_regression(x_values, y_values, "Max Temp", (30, 30))
# Out:
# The r-value is 0.2803913479139842

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

plot_linear_regression(x_values, y_values, "Max Temp", (-55, 5))
# Out:
# The r-value is 0.6434059927779884

# %% [markdown]
# ### Discussion about the linear relationship:
# - There is a moderate positive correlation between latitude and max temperature for northern hemisphere.
#
# - There is a strong positive correlation between latitude and max temperature for southern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")

plot_linear_regression(x_values, y_values, "Humidity", (50, 20))
# Out:
# The r-value is 0.011493649106166886

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")

plot_linear_regression(x_values, y_values, "Humidity", (-50, 30))
# Out:
# The r-value is 0.010222763652093927

# %% [markdown]
# **Discussion about the linear relationship:**
# - There is a weak positive correlation between latitude and humidity for northern hemisphere.
#
# - There is a weak positive correlation between latitude and humidity for southern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")


plot_linear_regression(x_values, y_values, "Cloudiness", (40, 20))
# Out:
# The r-value is 0.008340064859202205

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

plot_linear_regression(x_values, y_values, "Cloudiness", (-50, 2))
# Out:
# The r-value is 0.03842690567342498

# %% [markdown]
# **Discussion about the linear relationship:**
# - There is a weak positive correlation between latitude and cloudiness for northern hemisphere.
#
# - There is a moderate positive correlation between latitude and cloudiness for southern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")

plot_linear_regression(x_values, y_values, "Wind Speed", (50, 5))
# Out:
# The r-value is 0.008351792652432433

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression")

plot_linear_regression(x_values, y_values, "Wind Speed", (-50, 10))
# Out:
# The r-value is 0.043965954476351925

# %% [markdown]
# **Discussion about the linear relationship:**
# - There is a weak positive correlation between latitude and windspeed for northern hemisphere.
#
# - There is a weak positive correlation between latitude and windspeed for southern hemisphere.
